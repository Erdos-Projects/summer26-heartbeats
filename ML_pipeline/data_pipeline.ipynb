# %%
from data_preprocessing import HeartbeatDataProcessor

# %%
folder_path='../PAMAP2_Dataset/Protocol/'
filtered_df_path='./'
processed_data = HeartbeatDataProcessor(folder_path,filtered_df_path)
processed_data.preprocess_subjects(range(101,108))
# print(processed_data.df_filtered.head(3))
# print(processed_data.filtered_index.head(3))
# Out:
# successfully loaded subject 101
# successfully loaded subject 102
# successfully loaded subject 103
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 4
#       1 folder_path='../PAMAP2_Dataset/Protocol/'
#       2 filtered_df_path='./'
#       3 processed_data = HeartbeatDataProcessor(folder_path,filtered_df_path)
# ----> 4 processed_data.preprocess_subjects([101,102,103])#range(101,108))
#       5 print(processed_data.df_filtered.head(3))
#       6 print(processed_data.filtered_index.head(3))
#
# File c:\Users\Charlie\workspace\erdos_DS26\summer26-heartbeats\ML_pipeline\data_preprocessing.py:94, in HeartbeatDataProcessor.preprocess_subjects(self, subject_array)
#      92         print("successfully loaded subject",subject_num)
#      93 # 4. Combine all chunks into a single DataFrame
# ---> 94 self.df_filtered  = pd.concat(self.subject_segment_dict[subject_num],ignore_index=True)
#
# File c:\Users\Charlie\anaconda3\envs\erdos_ds_environment\Lib\site-packages\pandas\core\reshape\concat.py:407, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     402 else:  # pragma: no cover
#     403     raise ValueError(
#     404         "Only can inner (intersect) or outer (union) join the other axis"
#     405     )
# --> 407 objs, keys, ndims = _clean_keys_and_objs(objs, keys)
#     409 if sort is lib.no_default:
#     410     if axis == 0:
#
# File c:\Users\Charlie\anaconda3\envs\erdos_ds_environment\Lib\site-packages\pandas\core\reshape\concat.py:808, in _clean_keys_and_objs(objs, keys)
#     805     objs = list(objs)
#     807 if len(objs) == 0:
# --> 808     raise ValueError("No objects to concatenate")
#     810 if keys is not None:
#     811     if not isinstance(keys, Index):
#
# ValueError: No objects to concatenate
