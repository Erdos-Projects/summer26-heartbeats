# %%
from data_preprocessing import HeartbeatDataProcessor

# %%
folder_path='../data/PAMAP2_Dataset/Protocol/'
filtered_df_path='./'
processed_data = HeartbeatDataProcessor(folder_path,filtered_df_path)
processed_data.preprocess_subjects(range(101,108))
# print(processed_data.df_filtered.head(3))
# print(processed_data.filtered_index.head(3))

# %%
# extract one feature row per window segment; result is also stored on processed_data.features_df
features_df = processed_data.extract_all_features()

# each row is one window: 391 features (per-axis statistics + within-sensor axis
# correlations) plus the subject_id, interval_id, and activity_id labels
print(features_df.shape)
features_df.head(3)
